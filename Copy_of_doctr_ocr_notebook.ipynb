# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanpal5910/doctr-ocr-code-demo/blob/main/Copy_of_doctr_ocr_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mindee/doctr.git
# Out:
# Cloning into 'doctr'...
# remote: Enumerating objects: 54362, done.
# remote: Counting objects: 100% (1525/1525), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 54362 (delta 1074), reused 1497 (delta 1062), pack-reused 52837
# Receiving objects: 100% (54362/54362), 70.92 MiB | 20.71 MiB/s, done.
# Resolving deltas: 100% (38419/38419), done.

# %%
# !pip install -qe  doctr/.
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.4/271.4 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 9.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
model = ocr_predictor(det_arch='db_resnet50', reco_arch='crnn_vgg16_bn', pretrained=True)
# Out:
# ...
#   0%|          | 0/58758994 [00:00<?, ?it/s]

# %%
document = DocumentFile.from_images("/content/White Simple Invoice.jpg")

# %%
result = model(document)

# %%
json_response = result.export()

# %%
json_response
# Out:
# {'pages': [{'page_idx': 0,
#    'dimensions': (2000, 1414),
#    'orientation': {'value': None, 'confidence': None},
#    'language': {'value': None, 'confidence': None},
#    'blocks': [{'geometry': ((0.7361982850070721, 0.14453125),
#       (0.9157642326732673, 0.2109375)),
#      'lines': [{'geometry': ((0.7361982850070721, 0.14453125),
#         (0.9157642326732673, 0.1640625)),
#        'words': [{'value': 'Salford',
#          'confidence': 0.4376242756843567,
#          'geometry': ((0.7361982850070721, 0.14453125),
#           (0.835650194483734, 0.1630859375))},
#         {'value': '&',
#          'confidence': 0.999854564666748,
#          'geometry': ((0.841175300565771, 0.14453125),
#           (0.8674195544554455, 0.1640625))},
#         {'value': 'Co.',
#          'confidence': 0.9990239143371582,
#          'geometry': ((0.870182107496464, 0.14453125),
#           (0.9157642326732673, 0.1640625))}]},
#       {'geometry': ((0.7624425388967468, 0.1953125),
# ...

# %%
json_response['pages'][0]
# Out:
# {'page_idx': 0,
#  'dimensions': (2000, 1414),
#  'orientation': {'value': None, 'confidence': None},
#  'language': {'value': None, 'confidence': None},
#  'blocks': [{'geometry': ((0.7361982850070721, 0.14453125),
#     (0.9157642326732673, 0.2109375)),
#    'lines': [{'geometry': ((0.7361982850070721, 0.14453125),
#       (0.9157642326732673, 0.1640625)),
#      'words': [{'value': 'Salford',
#        'confidence': 0.4376242756843567,
#        'geometry': ((0.7361982850070721, 0.14453125),
#         (0.835650194483734, 0.1630859375))},
#       {'value': '&',
#        'confidence': 0.999854564666748,
#        'geometry': ((0.841175300565771, 0.14453125),
#         (0.8674195544554455, 0.1640625))},
#       {'value': 'Co.',
#        'confidence': 0.9990239143371582,
#        'geometry': ((0.870182107496464, 0.14453125),
#         (0.9157642326732673, 0.1640625))}]},
#     {'geometry': ((0.7624425388967468, 0.1953125),
#       (0.9130016796322489, 0.2109375)),
# ...

# %%
json_response['pages'][0]['blocks']
# Out:
# [{'geometry': ((0.7361982850070721, 0.14453125),
#    (0.9157642326732673, 0.2109375)),
#   'lines': [{'geometry': ((0.7361982850070721, 0.14453125),
#      (0.9157642326732673, 0.1640625)),
#     'words': [{'value': 'Salford',
#       'confidence': 0.4376242756843567,
#       'geometry': ((0.7361982850070721, 0.14453125),
#        (0.835650194483734, 0.1630859375))},
#      {'value': '&',
#       'confidence': 0.999854564666748,
#       'geometry': ((0.841175300565771, 0.14453125),
#        (0.8674195544554455, 0.1640625))},
#      {'value': 'Co.',
#       'confidence': 0.9990239143371582,
#       'geometry': ((0.870182107496464, 0.14453125),
#        (0.9157642326732673, 0.1640625))}]},
#    {'geometry': ((0.7624425388967468, 0.1953125),
#      (0.9130016796322489, 0.2109375)),
#     'words': [{'value': 'Tel:',
#       'confidence': 0.9935483336448669,
#       'geometry': ((0.7624425388967468, 0.1953125),
#        (0.7955931753889675, 0.2109375))},
# ...

# %%
json_response['pages'][0]['blocks'][0]
# Out:
# {'geometry': ((0.7361982850070721, 0.14453125),
#   (0.9157642326732673, 0.2109375)),
#  'lines': [{'geometry': ((0.7361982850070721, 0.14453125),
#     (0.9157642326732673, 0.1640625)),
#    'words': [{'value': 'Salford',
#      'confidence': 0.4376242756843567,
#      'geometry': ((0.7361982850070721, 0.14453125),
#       (0.835650194483734, 0.1630859375))},
#     {'value': '&',
#      'confidence': 0.999854564666748,
#      'geometry': ((0.841175300565771, 0.14453125),
#       (0.8674195544554455, 0.1640625))},
#     {'value': 'Co.',
#      'confidence': 0.9990239143371582,
#      'geometry': ((0.870182107496464, 0.14453125),
#       (0.9157642326732673, 0.1640625))}]},
#   {'geometry': ((0.7624425388967468, 0.1953125),
#     (0.9130016796322489, 0.2109375)),
#    'words': [{'value': 'Tel:',
#      'confidence': 0.9935483336448669,
#      'geometry': ((0.7624425388967468, 0.1953125),
#       (0.7955931753889675, 0.2109375))},
#     {'value': '+123-456-7890',
# ...

# %%
json_response['pages'][0]['blocks'][0]['lines']
# Out:
# [{'geometry': ((0.7361982850070721, 0.14453125),
#    (0.9157642326732673, 0.1640625)),
#   'words': [{'value': 'Salford',
#     'confidence': 0.4376242756843567,
#     'geometry': ((0.7361982850070721, 0.14453125),
#      (0.835650194483734, 0.1630859375))},
#    {'value': '&',
#     'confidence': 0.999854564666748,
#     'geometry': ((0.841175300565771, 0.14453125),
#      (0.8674195544554455, 0.1640625))},
#    {'value': 'Co.',
#     'confidence': 0.9990239143371582,
#     'geometry': ((0.870182107496464, 0.14453125),
#      (0.9157642326732673, 0.1640625))}]},
#  {'geometry': ((0.7624425388967468, 0.1953125),
#    (0.9130016796322489, 0.2109375)),
#   'words': [{'value': 'Tel:',
#     'confidence': 0.9935483336448669,
#     'geometry': ((0.7624425388967468, 0.1953125),
#      (0.7955931753889675, 0.2109375))},
#    {'value': '+123-456-7890',
#     'confidence': 0.7117335796356201,
#     'geometry': ((0.7928306223479491, 0.1962890625),
# ...

# %%
json_response['pages'][0]['blocks'][0]['lines'][0]['words']
# Out:
# [{'value': 'Salford',
#   'confidence': 0.4376242756843567,
#   'geometry': ((0.7361982850070721, 0.14453125),
#    (0.835650194483734, 0.1630859375))},
#  {'value': '&',
#   'confidence': 0.999854564666748,
#   'geometry': ((0.841175300565771, 0.14453125),
#    (0.8674195544554455, 0.1640625))},
#  {'value': 'Co.',
#   'confidence': 0.9990239143371582,
#   'geometry': ((0.870182107496464, 0.14453125),
#    (0.9157642326732673, 0.1640625))}]

# %%
json_response['pages'][0]['blocks'][0]['lines'][0]['words'][0]['value']
# Out:
# 'Salford'

# %%
for block in json_response['pages'][0]['blocks']:
    for line in block['lines']:
        for word_info in line['words']:
            value = word_info['value']
            print(value)
# Out:
# Salford
# &
# Co.
# Tel:
# +123-456-7890
# 123
# Anywhere
# St.,
# Any
# City,
# ST
# 12345
# INVOICE
# Invoice
# No:
# Bill
# to:
# 00000001
# Liceria
# &
# Co.
# 123
# Anywhere
# St.,
# Any
# City,
# ST
# 12345
# Description
# Logo
# Design
# Advertising
# Design
# Poster
# Design
# Brochure
# Design
# Content
# Writer
# Date:
# 12
# October,
# 2025
# Item
# 1.
# 2.
# 3.
# 4.
# 5.
# Price
# $200
# $500
# $500
# $200
# $500
# Amount
# $200
# $500
# $500
# $200
# $500
# Total
# $1900
# Bank
# Name:
# Bank
# Account:
# 0123
# Olivia
# Wilson
# Ifyou
# have
# any
# question
# please
# contact
# :
# helo@realygreatite.com
